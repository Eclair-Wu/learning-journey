# %%
from pyscf import gto
import numpy as np
mol = gto.M(
    atom='H 0 0 0; F 0 0 1.1',
    basis='3-21g')
ovlp=mol.intor('int1e_ovlp')
ao_1e=mol.intor('int1e_nuc')+mol.intor('int1e_kin')
ao_2e=mol.intor('int2e')
e_nuc=mol.energy_nuc()
# Out:
# 4.32963172570909

# %%
import rhf&uhf.py as hf
# Out:
#   Cell In[10], line 1
#     import rhf&uhf.py as hf
#               ^
# SyntaxError: invalid syntax
